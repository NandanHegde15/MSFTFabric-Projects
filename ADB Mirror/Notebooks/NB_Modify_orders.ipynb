# %%
# %sql 

drop table test_catalog.sales_data.orders;
truncate table test_catalog.config.cdc_control;

# %%
# %sql
CREATE OR REPLACE TABLE test_catalog.sales_data.orders (
    order_id INT,
    customer_id INT,
    product STRING,
    quantity INT,
    order_date DATE
)
TBLPROPERTIES (
    delta.enableChangeDataFeed = true
);

# %%
# %sql

select * from test_catalog.sales_data.orders;

# %%
# %sql

INSERT INTO test_catalog.sales_data.orders VALUES
(1001, 15, 'CPU', 6, '2025-11-01'),
(1002, 13, 'mouse pad', 7, '2025-11-01'),
(1003, 1, 'mouse pad', 1, '2025-11-02');

# %%
# %sql 

update test_catalog.sales_data.orders set quantity = 12 where order_id = 1002;

# %%
# %sql

delete from test_catalog.sales_data.orders where order_id = 1003;

# %%
# %sql
delete from test_catalog.sales_data.orders
